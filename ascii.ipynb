# %% [markdown]
# ### idk

# %%
# %pip install customtkinter
# %pip install art
# Out:
# Requirement already satisfied: customtkinter in /opt/homebrew/lib/python3.12/site-packages (5.2.2)
# Requirement already satisfied: darkdetect in /opt/homebrew/lib/python3.12/site-packages (from customtkinter) (0.8.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.12/site-packages (from customtkinter) (23.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.12 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting art
#   Downloading art-6.4-py3-none-any.whl.metadata (71 kB)
# Downloading art-6.4-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.6/608.6 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: art
# Successfully installed art-6.4
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.12 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.12/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.12/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.12/site-packages (from requests) (2024.2.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.12 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import customtkinter as ctk
from art import text2art, FONT_NAMES

# App Configuration
ctk.set_appearance_mode("light")

class AsciiArtApp(ctk.CTk):
    def __init__(self):
        super().__init__()

        # Color Palette
        self.bg_color = "#eaf6f6"  
        self.card_color = "#ffffff"  
        self.footer_color = "#2f6565"
        self.text_color = "#333333"  # Darker for better contrast

        # Window Configuration
        self.title("ASCII Art Generator")
        self.geometry("1000x700")  # Increased window size
        self.minsize(800, 600)
        self.configure(fg_color=self.bg_color)

        # Grid Configuration
        self.grid_columnconfigure(0, weight=1)
        self.grid_rowconfigure(2, weight=1)

        # Header
        self.header = ctk.CTkLabel(
            self, 
            text="ASCII Art Generator", 
            font=("Courier", 28, "bold"),
            text_color=self.text_color
        )
        self.header.grid(row=0, column=0, pady=10)

        # Input Area
        self.input_frame = ctk.CTkFrame(self, fg_color=self.card_color)
        self.input_frame.grid(row=1, column=0, pady=10, padx=20, sticky="ew")
        
        self.input_label = ctk.CTkLabel(
            self.input_frame, 
            text="Type your text:", 
            font=("Helvetica", 16),
            text_color=self.text_color
        )
        self.input_label.grid(row=0, column=0, padx=10)
        
        self.input_field = ctk.CTkEntry(
            self.input_frame,
            width=400,
            height=40,
            fg_color="#ffffff",
            text_color=self.text_color,
            border_width=2,
            corner_radius=10
        )
        self.input_field.grid(row=0, column=1, padx=10)
        self.input_field.bind("<KeyRelease>", self.generate_ascii)
        
        # Font Selection Dropdown
        self.font_label = ctk.CTkLabel(
            self.input_frame,
            text="Select Font:",
            font=("Helvetica", 16),
            text_color=self.text_color
        )
        self.font_label.grid(row=0, column=2, padx=10)
        
        self.font_var = ctk.StringVar(value="acrobatic")
        self.font_dropdown = ctk.CTkComboBox(
            self.input_frame,
            values=FONT_NAMES[:20],  # Limiting to 20 fonts for usability
            variable=self.font_var,
            command=self.generate_ascii  # Trigger ASCII update on font change
        )
        self.font_dropdown.grid(row=0, column=3, padx=10)

        # Output Area
        self.output_area = ctk.CTkTextbox(
            self,
            width=900,
            height=500,
            fg_color=self.card_color,
            text_color=self.text_color,
            corner_radius=10,
            font=("Courier", 14)
        )
        self.output_area.grid(row=2, column=0, pady=20, padx=20, sticky="nsew")
        self.output_area.configure(state="disabled")

        # Footer
        self.footer = ctk.CTkLabel(
            self,
            text="GWiST",
            font=("Helvetica", 14, "italic"),
            text_color="white",
            fg_color=self.footer_color,
            height=30
        )
        self.footer.grid(row=3, column=0, sticky="we")

    def generate_ascii(self, event=None):
        user_input = self.input_field.get()
        selected_font = self.font_var.get()
        
        if user_input.strip():
            ascii_art = text2art(user_input, font=selected_font)
        else:
            ascii_art = ""
        
        self.output_area.configure(state="normal")
        self.output_area.delete("1.0", "end")
        self.output_area.insert("1.0", ascii_art)
        self.output_area.configure(state="disabled")

if __name__ == "__main__":
    app = AsciiArtApp()
    app.mainloop()
